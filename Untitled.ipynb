# %%
import pandas as pd
import numpy as np
tempC=np.arange(0,110,10)
tempF=(tempC*1.8)+32
tempDF=pd.DataFrame({'(っ◔◡◔)っ ♥ tempurature ♥ 匚  🐤💜':tempC, "∙∙·▫▫ᵒᴼᵒ▫ₒₒ▫ᵒᴼᵒ▫ₒₒ▫ᵒᴼᵒ ⓉẸＭ𝐏𝐄𝔯ᵃ𝓉υℝє, ғ ᵒᴼᵒ▫ₒₒ▫ᵒᴼᵒ▫ₒₒ▫ᵒᴼᵒ▫▫·∙∙":tempF})
tempDF
# Out:
#     (っ◔◡◔)っ ♥ tempurature ♥ 匚  🐤💜  \
# 0                               0
# 1                              10
# 2                              20
# 3                              30
# 4                              40
# 5                              50
# 6                              60
# 7                              70
# 8                              80
# 9                              90
# 10                            100
#
#     ∙∙·▫▫ᵒᴼᵒ▫ₒₒ▫ᵒᴼᵒ▫ₒₒ▫ᵒᴼᵒ ⓉẸＭ𝐏𝐄𝔯ᵃ𝓉υℝє, ғ ᵒᴼᵒ▫ₒₒ▫ᵒᴼᵒ▫ₒₒ▫ᵒᴼᵒ▫▫·∙∙
# 0                                                32.0
# 1                                                50.0
# 2                                                68.0
# 3                                                86.0
# 4                                               104.0
# 5                                               122.0
# 6                                               140.0
# 7                                               158.0
# ...

# %%
import sqlite3
import matplotlib.pyplot as plt
dataDF=pd.ExcelFile('Volve production data.xlsx')
df1=dataDF.parse('Daily Production Data')
conn=sqlite3.connect("VolveProduction.db")
cur=conn.cursor()
#df1.to_sql("DailyRates", conn, if_exists="append", index = False)
conn.commit()
for code in (5351,5599,5693,5769,7078,7289,7405):
    testWellDF= pd.read_sql_query(f"SELECT DP_CHOKE_SIZE,BORE_OIL_VOL FROM DailyRates WHERE NPD_WELL_BORE_CODE={code};", conn)
    currFig = plt.figure(figsize=(7,5), dpi=100)
    fig, ax1 = plt.subplots()
    ax2 = ax1.twinx()
    ax1.plot(testWellDF['BORE_OIL_VOL'], color="red", ls='None', marker='.', markersize=5)
    ax2.plot(testWellDF['DP_CHOKE_SIZE'], color="green", ls='None', marker='.', markersize=5)
    ax1.set_title('Choke size and Oil Rate', fontsize=14, fontweight='bold')
    ax1.set_ylabel('Oil rate', color='green')
    ax2.set_ylabel('Choke Size', color='red')
